# %%
# Importing dependencies
import tweepy as tw
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Access keys from twitter developer account by signing into "developer.twitter.com"
consumer_key = 'I7xidj0vrAFQ38TPLQduGfHlz'
consumer_secret = 'mYZtbq8EtyfRjm0KnDcjWkCD49QmLFbZFXIW5hC1R5dcuAjumI'
access_token = '729203149068603392-0xerHtDvbNj0Qh3pYMbZIQ9gOKiauvw'
access_token_secret = 'momPBAdjmWy1lFqeROZdZsnRgeowbal7WPc4l9RAJKF6V'

# %%
# We'll authenticate and get the tweets to do the sentiment analysis
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret) # We're setting our access token on that auth object
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Getting data from twitter(tweets)
hashtag = "#INDIAvSL" #We're setting up an hashtag variable
query = tw.Cursor(api.search, q=hashtag).items(1000) #we're passing api.search meathon in tw.Cursor object in the end it's number of items we want in return
tweets = [{'Tweets':tweet.text, 'Timestamp': tweet.created_at} for tweet in query] # We're looping through each tweet in our query and extracting tweet.txt in the dictionary with respective keys
tweets
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-20-97dc273d7a86> in <module>
#       2 hashtag = "#INDIAvSL" #We're setting up an hashtag variable
#       3 query = tw.Cursor(api.search, q=hashtag).items(1000) #we're passing api.search meathon in tw.Cursor object in the end it's number of items we want in return
# ----> 4 tweets = [{'Tweets':tweet.text, 'Timestamp': tweet.created_at} for tweet in query] # We're looping through each tweet in our query and extracting tweet.txt in the dictionary with respective keys
#       5 tweets
#
# <ipython-input-20-97dc273d7a86> in <listcomp>(.0)
#       2 hashtag = "#INDIAvSL" #We're setting up an hashtag variable
#       3 query = tw.Cursor(api.search, q=hashtag).items(1000) #we're passing api.search meathon in tw.Cursor object in the end it's number of items we want in return
# ...
